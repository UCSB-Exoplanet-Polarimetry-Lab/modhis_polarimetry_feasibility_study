# %% [markdown]
# # CASE 1: sub_tint = 0, noise_percentage = 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles
import instrument_mm
import stokes

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Time intervals in seconds (1 to 10 minutes in 1-minute increments)
sub_tint = None # given in seconds
time_intervals = np.arange(1, 31) * 60  # Convert minutes to seconds
Q_injected = 0.01  # Example injected polarization level in Stokes Q
U_injected = 0
noise_percentage = 0.1

# Colors for each target
colors = ['blue', 'green', 'orange']

# Plot data storage
polarization_differences = {i: [] for i in range(len(targets))}

# Run the simulation for each target and each time interval
for target_idx, target in enumerate(targets):
    injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
    
    for t_int in time_intervals:
        # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
        S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
            ra=target["ra"], 
            dec=target["dec"], 
            observer_latitude=observer_latitude, 
            observer_longitude=observer_longitude, 
            jd_str=observation_date, 
            ut_start=observation_time, 
            t_int=t_int, 
            Q=Q_injected, 
            U=U_injected, 
            delta_HWP=0.5,
            noise_percentage=noise_percentage,
            include_V=False,
            sub_tint=sub_tint  # Sub-integration time in seconds
        )
        
        # Calculate retrieved polarization
        Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
        retrieved_polarization = np.sqrt(Q_retrieved**2 + U_retrieved**2)
        
        # Absolute difference in polarization percentage
        abs_diff_polarization = np.abs(injected_polarization - retrieved_polarization)
        polarization_differences[target_idx].append(abs_diff_polarization)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    altitude = angles.calculate_altitude(
        phi=observer_latitude, 
        delta=target["dec"], 
        H=angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )
    )
    plt.plot(time_intervals / 60, polarization_differences[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°, Alt: {altitude:.2f}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Absolute Difference in Polarization %')
plt.title("Absolute Difference in Polarization % vs. t_int for Different Targets - Q = " \
    + str(Q_injected) + ", U = " + str(U_injected) + ", Noise = " + \
    str(noise_percentage) + str("%"))
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # CASE 2: sub_tint = 1, noise_percentage = 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles
import instrument_mm
import stokes

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Time intervals in seconds (1 to 10 minutes in 1-minute increments)
sub_tint = 1 # given in seconds
time_intervals = np.arange(1, 31) * 60  # Convert minutes to seconds
Q_injected = 0.01  # Example injected polarization level in Stokes Q
U_injected = 0
noise_percentage = 0.1
TMT_matrix_noise = 0

# Colors for each target
colors = ['blue', 'green', 'orange']

# Plot data storage
polarization_differences = {i: [] for i in range(len(targets))}

# Run the simulation for each target and each time interval
for target_idx, target in enumerate(targets):
    injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
    
    for t_int in time_intervals:
        # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
        S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
            ra=target["ra"], 
            dec=target["dec"], 
            observer_latitude=observer_latitude, 
            observer_longitude=observer_longitude, 
            jd_str=observation_date, 
            ut_start=observation_time, 
            t_int=t_int, 
            Q=Q_injected, 
            U=U_injected, 
            delta_HWP=0.5,
            noise_percentage=noise_percentage,
            include_V=False,
            sub_tint=sub_tint,  # Sub-integration time in seconds
            observable = "single_difference"
        )
        
        # Calculate retrieved polarization
        Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
        retrieved_polarization = np.sqrt(Q_retrieved**2 + U_retrieved**2)
        
        # Absolute difference in polarization percentage
        abs_diff_polarization = np.abs(injected_polarization - retrieved_polarization)
        polarization_differences[target_idx].append(abs_diff_polarization)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    altitude = angles.calculate_altitude(
        phi=observer_latitude, 
        delta=target["dec"], 
        H=angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )
    )
    plt.plot(time_intervals / 60, polarization_differences[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°, Alt: {altitude:.2f}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Absolute Difference in DoLP')
plt.title("Absolute Difference in DoLP vs. t_int for Different Targets - Q = " \
    + str(Q_injected) + ", U = " + str(U_injected) + ", $\sigma_I$ = " + \
    str(noise_percentage) + "%" + ", sub_tint = " + str(sub_tint) + "s" + \
    ", $\sigma_{mm}$ = " + str(TMT_matrix_noise) + "%")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# single_difference_matrix  [[ 9.77067721e-01  3.18739568e-03  1.92283923e-02  5.84933831e-03]
#  [ 1.95127346e-04 -9.63827718e-01  1.59420490e-01  3.47945359e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77067721e-01  3.18739568e-03  1.92283923e-02  5.84933831e-03]
#  [ 1.95127346e-04 -9.63827718e-01  1.59420490e-01  3.47945359e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77098605e-01  2.10617652e-02 -5.45549086e-03 -8.07869360e-04]
#  [-1.67245155e-03  1.72406552e-01  9.26920286e-01  2.60202903e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_difference_matrix  [[ 0.97706408  0.00768571  0.01773697  0.00577057]
#  [-0.00426746 -0.95901803  0.18789109 -0.02248876]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# single_sum_matrix  [[ 0.97706408  0.00768571  0.01773697  0.00577057]
#  [-0.00426746 -0.95901803  0.18789109 -0.02248876]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# single_difference_matrix  [[ 9.77053262e-01 -3.82036681e-03 -1.83654560e-02 -5.82703020e-03]
#  [-3.52161123e-04  9.61884575e-01 -1.70688007e-01 -3.39113060e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77053262e-01 -3.82036681e-03 -1.83654560e-02 -5.82703020e-03]
#  [-3.52161123e-04  9.61884575e-01 -1.70688007e-01 -3.39113060e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_difference_matrix  [[ 9.77019355e-01 -1.69912193e-02  5.46408907e-03  7.69242908e-04]
#  [-2.34853212e-03 -1.71595069e-01 -9.09230489e-01 -3.16953486e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77019355e-01 -1.69912193e-02  5.46408907e-03  7.69242908e-04]
#  [-2.34853212e-03 -1.71595069e-01 -9.09230489e-01 -3.16953486e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_difference_matrix  [[ 9.77097983e-01  2.08565634e-02 -6.09257846e-03 -8.25699434e-04]
#  [-2.27109116e-03  1.74461611e-01  9.26433575e-01  2.60553416e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77097983e-01  2.08565634e-02 -6.09257846e-03 -8.25699434e-04]
#  [-2.27109116e-03  1.74461611e-01  9.26433575e-01  2.60553416e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_difference_matrix  [[ 0.97706367  0.00821307  0.01747986  0.00576039]
#  [-0.00479394 -0.95804669  0.19186404 -0.0291777 ]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# single_sum_matrix  [[ 0.97706367  0.00821307  0.01747986  0.00576039]
#  [-0.00479394 -0.95804669  0.19186404 -0.0291777 ]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# single_difference_matrix  [[ 9.77052611e-01 -4.36598103e-03 -1.82118416e-02 -5.81657717e-03]
#  [-8.77902126e-04  9.61355206e-01 -1.74826466e-01 -2.69493093e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77052611e-01 -4.36598103e-03 -1.82118416e-02 -5.81657717e-03]
#  [-8.77902126e-04  9.61355206e-01 -1.74826466e-01 -2.69493093e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_difference_matrix  [[ 9.77018898e-01 -1.67930108e-02  5.96923541e-03  7.87740112e-04]
#  [-2.82836605e-03 -1.73288593e-01 -9.08932868e-01 -3.16871125e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# single_sum_matrix  [[ 9.77018898e-01 -1.67930108e-02  5.96923541e-03  7.87740112e-04]
#  [-2.82836605e-03 -1.73288593e-01 -9.08932868e-01 -3.16871125e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 44
#      40 injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
#      42 for t_int in time_intervals:
#      43     # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
# ---> 44     S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
#      45         ra=target["ra"],
#      46         dec=target["dec"],
#      47         observer_latitude=observer_latitude,
#      48         observer_longitude=observer_longitude,
#      49         jd_str=observation_date,
#      50         ut_start=observation_time,
#      51         t_int=t_int,
#      52         Q=Q_injected,
#      53         U=U_injected,
#      54         delta_HWP=0.5,
#      55         noise_percentage=noise_percentage,
#      56         include_V=False,
#      57         sub_tint=sub_tint,  # Sub-integration time in seconds
#      58         observable = "single_difference"
#      59     )
#      61     # Calculate retrieved polarization
#      62     Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
#
# File ~/Github/modhis_polarimetry_feasibility_study/notebooks/../python/instrument_mm.py:421, in calculate_input_Q_U_observing_sequence_matrix_inversion(ra, dec, observer_latitude, observer_longitude, jd_str, ut_start, t_int, Q, U, delta_HWP, noise_percentage, include_V, sub_tint, use_sum, matrix_noise, hour_angle, TMT_matrix_noise, NFIRAOS_matrix_noise, MODHIS_matrix_noise, observable)
#     418 sub_altitude.append(altitude)
#     420 o_matrix, _ = MODHIS_full_system_mm(pa=pa, altitude=altitude, delta_HWP=delta_HWP, HWP_ang=HWP_ang, wollaston_beam="o")
# --> 421 e_matrix, _ = MODHIS_full_system_mm(pa=pa, altitude=altitude, delta_HWP=delta_HWP, HWP_ang=HWP_ang, wollaston_beam="e")
#     423 o_stokes = propagate_on_sky_source(Q=Q, U=U, inst_matrix=o_matrix)
#     424 e_stokes = propagate_on_sky_source(Q=Q, U=U, inst_matrix=e_matrix)
#
# File ~/Github/modhis_polarimetry_feasibility_study/notebooks/../python/instrument_mm.py:28, in MODHIS_full_system_mm(pa, altitude, delta_HWP, HWP_ang, wollaston_beam, TMT_matrix_noise, NFIRAOS_matrix_noise, MODHIS_matrix_noise)
#      25 parang_rot.properties['pa'] = pa
#      27 # All telescope mirrors
# ---> 28 TMT = cmm.ArbitraryMatrix(name = "TMT")
#      29 TMT.properties['mm'] = TMT_matrix(TMT_matrix_noise = TMT_matrix_noise)
#      31  # TODO: Verify if this is positive or negative
#      32 # Altitude angle rotation
#
# File ~/Github/pyMuellerMat/pyMuellerMat/common_mms.py:136, in ArbitraryMatrix.__init__(self, name)
#     135 def __init__(self, name='ArbitraryMatrix'):
# --> 136     super(ArbitraryMatrix, self).__init__(arbitrary_matrix_function, name=name)
#
# File ~/Github/pyMuellerMat/pyMuellerMat/MuellerMat.py:52, in MuellerMatrix.__init__(self, mueller_matrix_function, name)
#      46 self.function = mueller_matrix_function
#      48 # TODO: Perhaps make a check so the function has no arguments (but can have keyword arguments)
#      49
#      50 # Get the function's keyword arguments - I found this example of how to do this here: https://stackoverflow.com/questions/11915032/get-keyword-arguments-for-function-python
#      51 # TODO: There may be a python 3 compatability problem here.
# ---> 52 argspec = inspect.getargspec(self.function)
#      54 if argspec.defaults is not None:
#      55     self.property_list = argspec.args[-len(argspec.defaults):]
#
# File ~/anaconda3/envs/vampires_calibration_py310/lib/python3.10/inspect.py:1235, in getargspec(func)
#    1212 """Get the names and default values of a function's parameters.
#    1213
#    1214 A tuple of four things is returned: (args, varargs, keywords, defaults).
#    (...)
#    1229 Deprecated since Python 3.5, use `inspect.getfullargspec()`.
#    1230 """
#    1231 warnings.warn("inspect.getargspec() is deprecated since Python 3.0, "
#    1232               "use inspect.signature() or inspect.getfullargspec()",
#    1233               DeprecationWarning, stacklevel=2)
#    1234 args, varargs, varkw, defaults, kwonlyargs, kwonlydefaults, ann = \
# -> 1235     getfullargspec(func)
#    1236 if kwonlyargs or ann:
#    1237     raise ValueError("Function has keyword-only parameters or annotations"
#    1238                      ", use inspect.signature() API which can support them")
#
# File ~/anaconda3/envs/vampires_calibration_py310/lib/python3.10/inspect.py:1333, in getfullargspec(func)
#    1329 if not defaults:
#    1330     # compatibility with 'func.__defaults__'
#    1331     defaults = None
# -> 1333 return FullArgSpec(posonlyargs + args, varargs, varkw, defaults,
#    1334                    kwonlyargs, kwdefaults, annotations)
#
# File <string>:1, in <lambda>(_cls, args, varargs, varkw, defaults, kwonlyargs, kwonlydefaults, annotations)
#
# KeyboardInterrupt:

# %% [markdown]
# # Plotting vs Hour Angle Change

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Integration times in seconds (1 to 30 minutes in 1-minute increments)
time_intervals = np.arange(1, 31) * 60  # Convert minutes to seconds

# Colors for each target
colors = ['blue', 'green', 'orange']

# Store hour angle changes for each target and time interval
hour_angle_changes = {i: [] for i in range(len(targets))}

# Calculate hour angle change for each target and integration time
for target_idx, target in enumerate(targets):
    for t_int in time_intervals:
        # Calculate start hour angle
        ha_start = angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )

        # Calculate the end time in UT by adding the integration time in seconds
        ut_start_hours, ut_start_minutes, ut_start_seconds = map(int, observation_time.split(":"))
        ut_start_decimal = ut_start_hours + ut_start_minutes / 60.0 + ut_start_seconds / 3600.0
        ut_end_decimal = ut_start_decimal + t_int / 3600.0
        ut_end = f"{int(ut_end_decimal // 1):02}:{int((ut_end_decimal % 1) * 60):02}:{int(((ut_end_decimal % 1) * 3600) % 60):02}"

        # Calculate end hour angle
        ha_end = angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=ut_end, 
            jd_str=observation_date
        )

        # Calculate and store the absolute change in hour angle
        ha_change = np.abs(ha_end - ha_start)
        hour_angle_changes[target_idx].append(ha_change)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    plt.plot(time_intervals / 60, hour_angle_changes[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Hour Angle Change (degrees)')
plt.title("Hour Angle Change vs. Integration Time for Different Targets")
plt.legend()
plt.grid(True)
plt.show()
