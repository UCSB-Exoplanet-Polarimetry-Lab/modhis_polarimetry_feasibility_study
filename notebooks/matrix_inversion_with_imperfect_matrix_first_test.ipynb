# %% [markdown]
# # CASE 1: sub_tint = None, meas_noise = 0%, matrix_noise = 1%

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles
import instrument_mm
import stokes

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Time intervals in seconds (1 to 10 minutes in 1-minute increments)
sub_tint = None # given in seconds
time_intervals = np.arange(1, 10) * 60  # Convert minutes to seconds
Q_injected = 0.01  # Example injected polarization level in Stokes Q
U_injected = 0
noise_percentage = 0.1
TMT_matrix_noise, NFIRAOS_matrix_noise, MODHIS_matrix_noise = 1, 1, 1
observable = "intensities"

# Colors for each target
colors = ['blue', 'green', 'orange']

# Plot data storage
polarization_differences = {i: [] for i in range(len(targets))}

# Run the simulation for each target and each time interval
for target_idx, target in enumerate(targets):
    injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
    
    for t_int in time_intervals:
        # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
        S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
            ra=target["ra"], 
            dec=target["dec"], 
            observer_latitude=observer_latitude, 
            observer_longitude=observer_longitude, 
            jd_str=observation_date, 
            ut_start=observation_time, 
            t_int=t_int, 
            Q=Q_injected, 
            U=U_injected, 
            delta_HWP=0.5,
            noise_percentage=noise_percentage,
            include_V=False,
            sub_tint=sub_tint,  # Sub-integration time in seconds
            TMT_matrix_noise = TMT_matrix_noise,
            NFIRAOS_matrix_noise = NFIRAOS_matrix_noise,
            MODHIS_matrix_noise = MODHIS_matrix_noise,
            observable = observable
        )
        
        # Calculate retrieved polarization
        Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
        retrieved_polarization = np.sqrt(Q_retrieved**2 + U_retrieved**2)
        
        # Absolute difference in polarization percentage
        abs_diff_polarization = np.abs(injected_polarization - retrieved_polarization)
        polarization_differences[target_idx].append(abs_diff_polarization)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    altitude = angles.calculate_altitude(
        phi=observer_latitude, 
        delta=target["dec"], 
        H=angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )
    )
    plt.plot(time_intervals / 60, polarization_differences[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°, Alt: {altitude:.2f}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Absolute Difference in DoLP')
plt.title("Absolute Difference in DoLP vs. t_int for Different Targets - Q = " \
    + str(Q_injected) + ", U = " + str(U_injected) + ", $\sigma_I$ = " + \
    str(noise_percentage) + "%" + ", sub_tint = " + str(sub_tint) + "s" + \
    ", $\sigma_{mm}$ = " + str(TMT_matrix_noise) + "%" + ", observable = " + observable)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # CASE 2: sub_tint = None, meas_noise = 0%, matrix_noise = 0%

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles
import instrument_mm
import stokes

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Time intervals in seconds (1 to 10 minutes in 1-minute increments)
sub_tint = None # given in seconds
time_intervals = np.arange(1, 31) * 60  # Convert minutes to seconds
Q_injected = 0.01  # Example injected polarization level in Stokes Q
U_injected = 0
noise_percentage = 0.1
TMT_matrix_noise = 0
NFIRAOS_matrix_noise = 0
MODHIS_matrix_noise = 0

# Colors for each target
colors = ['blue', 'green', 'orange']

# Plot data storage
polarization_differences = {i: [] for i in range(len(targets))}

# Run the simulation for each target and each time interval
for target_idx, target in enumerate(targets):
    injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
    
    for t_int in time_intervals:
        # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
        S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
            ra=target["ra"], 
            dec=target["dec"], 
            observer_latitude=observer_latitude, 
            observer_longitude=observer_longitude, 
            jd_str=observation_date, 
            ut_start=observation_time, 
            t_int=t_int, 
            Q=Q_injected, 
            U=U_injected, 
            delta_HWP=0.5,
            noise_percentage=noise_percentage,
            include_V=False,
            sub_tint=sub_tint,  # Sub-integration time in seconds
            TMT_matrix_noise = TMT_matrix_noise,
            NFIRAOS_matrix_noise = NFIRAOS_matrix_noise,
            MODHIS_matrix_noise = MODHIS_matrix_noise
        )
        
        # Calculate retrieved polarization
        Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
        retrieved_polarization = np.sqrt(Q_retrieved**2 + U_retrieved**2)
        
        # Absolute difference in polarization percentage
        abs_diff_polarization = np.abs(injected_polarization - retrieved_polarization)
        polarization_differences[target_idx].append(abs_diff_polarization)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    altitude = angles.calculate_altitude(
        phi=observer_latitude, 
        delta=target["dec"], 
        H=angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )
    )
    plt.plot(time_intervals / 60, polarization_differences[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°, Alt: {altitude:.2f}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Absolute Difference in Polarization %')
plt.title("Absolute Difference in Polarization % vs. t_int for Different Targets - Q = " \
    + str(Q_injected) + ", U = " + str(U_injected) + ", Noise = " + \
    str(noise_percentage) + str("%") + ", sub_tint = " + str(sub_tint) + "s" + \
    " Matrix Noise = " + str(TMT_matrix_noise) + "%")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # CASE 3: sub_tint = 1s, meas_noise = 0.1%, matrix_noise = 1%

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles
import instrument_mm
import stokes

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Time intervals in seconds (1 to 10 minutes in 1-minute increments)
sub_tint = 1 # given in seconds
time_intervals = np.arange(1, 31) * 60  # Convert minutes to seconds
Q_injected = 0.01  # Example injected polarization level in Stokes Q
U_injected = 0
noise_percentage = 0.1
TMT_matrix_noise = 1
NFIRAOS_matrix_noise = 1
MODHIS_matrix_noise = 1

# Colors for each target
colors = ['blue', 'green', 'orange']

# Plot data storage
polarization_differences = {i: [] for i in range(len(targets))}

# Run the simulation for each target and each time interval
for target_idx, target in enumerate(targets):
    injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
    
    for t_int in time_intervals:
        # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
        S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
            ra=target["ra"], 
            dec=target["dec"], 
            observer_latitude=observer_latitude, 
            observer_longitude=observer_longitude, 
            jd_str=observation_date, 
            ut_start=observation_time, 
            t_int=t_int, 
            Q=Q_injected, 
            U=U_injected, 
            delta_HWP=0.5,
            noise_percentage=noise_percentage,
            include_V=False,
            sub_tint=sub_tint,  # Sub-integration time in seconds
            TMT_matrix_noise = TMT_matrix_noise,
            NFIRAOS_matrix_noise = NFIRAOS_matrix_noise,
            MODHIS_matrix_noise = MODHIS_matrix_noise,
            observable = "intensities"
        )
        
        # Calculate retrieved polarization
        Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
        retrieved_polarization = np.sqrt(Q_retrieved**2 + U_retrieved**2)
        
        # Absolute difference in polarization percentage
        abs_diff_polarization = np.abs(injected_polarization - retrieved_polarization)
        polarization_differences[target_idx].append(abs_diff_polarization)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    altitude = angles.calculate_altitude(
        phi=observer_latitude, 
        delta=target["dec"], 
        H=angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )
    )
    plt.plot(time_intervals / 60, polarization_differences[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°, Alt: {altitude:.2f}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Absolute Difference in Polarization %')
plt.title("Absolute Difference in Polarization % vs. t_int for Different Targets - Q = " \
    + str(Q_injected) + ", U = " + str(U_injected) + ", Noise = " + \
    str(noise_percentage) + str("%") + ", sub_tint = " + str(sub_tint) + "s" + \
    " Matrix Noise = " + str(TMT_matrix_noise) + "%")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# o_matrix_avg:  [[5.23872991 0.32770493 0.03960441 0.08963743]
#  [5.23872991 0.32770493 0.03960441 0.08963743]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]]
# o_matrix_avg:  [[ 5.23915051 -0.32920904  0.00789298 -0.07797442]
#  [ 5.23915051 -0.32920904  0.00789298 -0.07797442]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 5.23887034  0.10784936  0.03816426 -0.24642994]
#  [ 5.23887034  0.10784936  0.03816426 -0.24642994]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 5.23901007 -0.10935347  0.00933314  0.25809295]
#  [ 5.23901007 -0.10935347  0.00933314  0.25809295]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# Measurement Matrix Shape: (8, 4)
# Measurements Vector Shape: (8,)
# Modified Measurement Matrix Shape: (8, 3)
# Modified Measurement Matrix:  [[ 5.23872991  0.32770493  0.03960441]
#  [ 5.23574098 -0.33538164 -0.04148986]
#  [ 5.23915051 -0.32920904  0.00789298]
#  [ 5.23530893  0.33924016 -0.00571697]
#  [ 5.23887034  0.10784936  0.03816426]
#  [ 5.23555591 -0.04591347 -0.0348031 ]
#  [ 5.23901007 -0.10935347  0.00933314]
#  [ 5.23549401  0.04977199 -0.01240373]]
# o_matrix_avg:  [[ 0.52641822 -0.19839552  0.0739918  -0.04285131]
#  [ 0.52641822 -0.19839552  0.0739918  -0.04285131]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.52762857  0.19999268 -0.03884481 -0.0590388 ]
#  [ 0.52762857  0.19999268 -0.03884481 -0.0590388 ]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.52685169 -0.05096598 -0.19682044 -0.07947023]
#  [ 0.52685169 -0.05096598 -0.19682044 -0.07947023]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.52719511  0.05256314  0.23196743 -0.02241988]
#  [ 0.52719511  0.05256314  0.23196743 -0.02241988]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# Measurement Matrix Shape: (8, 4)
# Measurements Vector Shape: (8,)
# Modified Measurement Matrix Shape: (8, 3)
# Modified Measurement Matrix:  [[ 0.52641822 -0.19839552  0.0739918 ]
#  [ 0.52635336  0.20369342 -0.04856779]
#  [ 0.52762857  0.19999268 -0.03884481]
#  [ 0.5251216  -0.20065484  0.01359434]
#  [ 0.52685169 -0.05096598 -0.19682044]
#  [ 0.52583749  0.02975259  0.20019508]
#  [ 0.52719511  0.05256314  0.23196743]
#  [ 0.52563747 -0.026714   -0.23516853]]
# o_matrix_avg:  [[-1.01322383 -0.0289457  -0.0309831  -0.00825306]
#  [-1.01322383 -0.0289457  -0.0309831  -0.00825306]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[-1.01424826  0.02705738  0.02638599  0.0233108 ]
#  [-1.01424826  0.02705738  0.02638599  0.0233108 ]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[-1.01369166  0.00128783  0.33316934  0.18966588]
#  [-1.01369166  0.00128783  0.33316934  0.18966588]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[-1.01378043 -0.00317615 -0.33776645 -0.17460815]
#  [-1.01378043 -0.00317615 -0.33776645 -0.17460815]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# Measurement Matrix Shape: (8, 4)
# Measurements Vector Shape: (8,)
# Modified Measurement Matrix Shape: (8, 3)
# Modified Measurement Matrix:  [[-1.01322383 -0.0289457  -0.0309831 ]
#  [-1.01080994  0.02704512  0.08475946]
#  [-1.01424826  0.02705738  0.02638599]
#  [-1.00981594 -0.0288     -0.080122  ]
#  [-1.01369166  0.00128783  0.33316934]
#  [-1.01043939  0.00145024 -0.32324715]
#  [-1.01378043 -0.00317615 -0.33776645]
#  [-1.01018649 -0.00320512  0.32788462]]
# o_matrix_avg:  [[ 0.06933647 -0.45159402  0.11548106  0.01885222]
#  [ 0.06933647 -0.45159402  0.11548106  0.01885222]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.07060985  0.45031295 -0.1209833  -0.01321887]
#  [ 0.07060985  0.45031295 -0.1209833  -0.01321887]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.06984664 -0.11397373 -0.48625008 -0.07787922]
#  [ 0.06984664 -0.11397373 -0.48625008 -0.07787922]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[0.07009968 0.11269267 0.48074783 0.08351257]
#  [0.07009968 0.11269267 0.48074783 0.08351257]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]]
# Measurement Matrix Shape: (8, 4)
# Measurements Vector Shape: (8,)
# Modified Measurement Matrix Shape: (8, 3)
# Modified Measurement Matrix:  [[ 0.06933647 -0.45159402  0.11548106]
#  [ 0.07152254  0.45568981 -0.08906139]
#  [ 0.07060985  0.45031295 -0.1209833 ]
#  [ 0.07023831 -0.456465    0.09465447]
#  [ 0.06984664 -0.11397373 -0.48625008]
#  [ 0.07097228  0.08833989  0.49161205]
#  [ 0.07009968  0.11269267  0.48074783]
#  [ 0.07078857 -0.08911509 -0.48601897]]
# o_matrix_avg:  [[ 0.22771989 -0.4786325   0.0738478   0.04422449]
#  [ 0.22771989 -0.4786325   0.0738478   0.04422449]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.23074127  0.48134468 -0.05891803 -0.02799672]
#  [ 0.23074127  0.48134468 -0.05891803 -0.02799672]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[ 0.22906553 -0.07182691 -0.24943149 -0.32239132]
#  [ 0.22906553 -0.07182691 -0.24943149 -0.32239132]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
# o_matrix_avg:  [[0.22939564 0.07453909 0.26436125 0.3386191 ]
#  [0.22939564 0.07453909 0.26436125 0.3386191 ]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]]
# Measurement Matrix Shape: (8, 4)
# Measurements Vector Shape: (8,)
# Modified Measurement Matrix Shape: (8, 3)
# Modified Measurement Matrix:  [[ 0.22771989 -0.4786325   0.0738478 ]
#  [ 0.23359808  0.48848484 -0.05212695]
#  [ 0.23074127  0.48134468 -0.05891803]
#  [ 0.23053562 -0.48811516  0.03697952]
#  [ 0.22906553 -0.07182691 -0.24943149]
#  [ 0.23210259  0.03236768  0.25611307]
#  [ 0.22939564  0.07453909  0.26436125]
#  [ 0.23203111 -0.031998   -0.2712605 ]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 46
#      42 injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
#      44 for t_int in time_intervals:
#      45     # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
# ---> 46     S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
#      47         ra=target["ra"],
#      48         dec=target["dec"],
#      49         observer_latitude=observer_latitude,
#      50         observer_longitude=observer_longitude,
#      51         jd_str=observation_date,
#      52         ut_start=observation_time,
#      53         t_int=t_int,
#      54         Q=Q_injected,
#      55         U=U_injected,
#      56         delta_HWP=0.5,
#      57         noise_percentage=noise_percentage,
#      58         include_V=False,
#      59         sub_tint=sub_tint,  # Sub-integration time in seconds
#      60         TMT_matrix_noise = TMT_matrix_noise,
#      61         NFIRAOS_matrix_noise = NFIRAOS_matrix_noise,
#      62         MODHIS_matrix_noise = MODHIS_matrix_noise,
#      63         observable = "intensities"
#      64     )
#      66     # Calculate retrieved polarization
#      67     Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
#
# File ~/Github/modhis_polarimetry_feasibility_study/notebooks/../python/instrument_mm.py:421, in calculate_input_Q_U_observing_sequence_matrix_inversion(ra, dec, observer_latitude, observer_longitude, jd_str, ut_start, t_int, Q, U, delta_HWP, noise_percentage, include_V, sub_tint, use_sum, matrix_noise, hour_angle, TMT_matrix_noise, NFIRAOS_matrix_noise, MODHIS_matrix_noise, observable)
#     418 sub_altitude.append(altitude)
#     420 o_matrix, _ = MODHIS_full_system_mm(pa=pa, altitude=altitude, delta_HWP=delta_HWP, HWP_ang=HWP_ang, wollaston_beam="o")
# --> 421 e_matrix, _ = MODHIS_full_system_mm(pa=pa, altitude=altitude, delta_HWP=delta_HWP, HWP_ang=HWP_ang, wollaston_beam="e")
#     423 o_stokes = propagate_on_sky_source(Q=Q, U=U, inst_matrix=o_matrix)
#     424 e_stokes = propagate_on_sky_source(Q=Q, U=U, inst_matrix=e_matrix)
#
# File ~/Github/modhis_polarimetry_feasibility_study/notebooks/../python/instrument_mm.py:33, in MODHIS_full_system_mm(pa, altitude, delta_HWP, HWP_ang, wollaston_beam, TMT_matrix_noise, NFIRAOS_matrix_noise, MODHIS_matrix_noise)
#      29 TMT.properties['mm'] = TMT_matrix(TMT_matrix_noise = TMT_matrix_noise)
#      31  # TODO: Verify if this is positive or negative
#      32 # Altitude angle rotation
# ---> 33 alt_rot = cmm.Rotator(name = "altitude")
#      34 alt_rot.properties['pa'] = altitude
#      36 # HWP for differencing - assumed to be before NFIRAOS
#
# File ~/Github/pyMuellerMat/pyMuellerMat/common_mms.py:95, in Rotator.__init__(self, name)
#      90 class Rotator(MuellerMat.MuellerMatrix):
#      91     '''
#      92     A MuellerMat.MuellerMatrix child class for a general rotator
#      93     '''
# ---> 95     def __init__(self, name='Rotator'):
#      96         super(Rotator, self).__init__(rotator_function, name=name)
#
# KeyboardInterrupt:

# %% [markdown]
# # CASE 4: sub_tint = 1s, meas_noise = 0.1%, matrix_noise = 0.1%

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../python/')
import angles
import instrument_mm
import stokes

# Define observer parameters
observer_latitude = 20.0  # Latitude of Mauna Kea in degrees
observer_longitude = -155.5  # Longitude of Mauna Kea in degrees

# Define target parameters
targets = [
    {"ra": 31.791, "dec": 23.462},  # Hamal (Alpha Arietis)
    {"ra": 51.079, "dec": 49.861},  # Mirfak (Alpha Persei)
    {"ra": 37.954, "dec": 89.264},  # Polaris (Alpha Ursae Minoris)
]

# Observation date and time
observation_date = "2460614.91667"  # JD for 10/31/2024
observation_time = "10:00:00"   # UT time to get peak at midnight HST

# Time intervals in seconds (1 to 10 minutes in 1-minute increments)
sub_tint = 1 # given in seconds
time_intervals = np.arange(1, 31) * 60  # Convert minutes to seconds
Q_injected = 0.01  # Example injected polarization level in Stokes Q
U_injected = 0
noise_percentage = 0.1
TMT_matrix_noise = 0.1
NFIRAOS_matrix_noise = 0.1
MODHIS_matrix_noise = 0.1

# Colors for each target
colors = ['blue', 'green', 'orange']

# Plot data storage
polarization_differences = {i: [] for i in range(len(targets))}

# Run the simulation for each target and each time interval
for target_idx, target in enumerate(targets):
    injected_polarization = np.sqrt(Q_injected**2 + U_injected**2)
    
    for t_int in time_intervals:
        # Run matrix inversion function with dynamic PA and altitude, using sub_tint = 1 second
        S_in_retrieved = instrument_mm.calculate_input_Q_U_observing_sequence_matrix_inversion(
            ra=target["ra"], 
            dec=target["dec"], 
            observer_latitude=observer_latitude, 
            observer_longitude=observer_longitude, 
            jd_str=observation_date, 
            ut_start=observation_time, 
            t_int=t_int, 
            Q=Q_injected, 
            U=U_injected, 
            delta_HWP=0.5,
            noise_percentage=noise_percentage,
            include_V=False,
            sub_tint=sub_tint,  # Sub-integration time in seconds
            TMT_matrix_noise = TMT_matrix_noise,
            NFIRAOS_matrix_noise = NFIRAOS_matrix_noise,
            MODHIS_matrix_noise = MODHIS_matrix_noise
        )
        
        # Calculate retrieved polarization
        Q_retrieved, U_retrieved = S_in_retrieved[1], S_in_retrieved[2]
        retrieved_polarization = np.sqrt(Q_retrieved**2 + U_retrieved**2)
        
        # Absolute difference in polarization percentage
        abs_diff_polarization = np.abs(injected_polarization - retrieved_polarization)
        polarization_differences[target_idx].append(abs_diff_polarization)

# Plotting the results
plt.figure(figsize=(10, 6))
for target_idx, target in enumerate(targets):
    altitude = angles.calculate_altitude(
        phi=observer_latitude, 
        delta=target["dec"], 
        H=angles.calculate_hour_angle(
            ra=target["ra"], 
            observer_longitude=observer_longitude, 
            ut=observation_time, 
            jd_str=observation_date
        )
    )
    plt.plot(time_intervals / 60, polarization_differences[target_idx], '-o', color=colors[target_idx],
             label=f'Target RA: {target["ra"]}°, Dec: {target["dec"]}°, Alt: {altitude:.2f}°')

# Plot settings
plt.xlabel('Integration Time t_int (minutes)')
plt.ylabel('Absolute Difference in DoLP')
plt.title("Absolute Difference in DoLP vs. t_int for Different Targets - Q = " \
    + str(Q_injected) + ", U = " + str(U_injected) + ", $\sigma_I$ = " + \
    str(noise_percentage) + "%" + ", sub_tint = " + str(sub_tint) + "s" + \
    ", $\sigma_{mm}$ = " + str(TMT_matrix_noise) + "%")

plt.legend()
plt.grid(True)
plt.show()
